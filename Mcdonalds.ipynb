# %% [markdown]
# <a href="https://colab.research.google.com/github/OscarAliM/Matematicas_y_Ciencia_de_Datos/blob/main/Mcdonalds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Menú de McDonalds***

# %%
import pandas as pd
mc=pd.read_csv('menu_mcdonalds.csv')
mc
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# ...

# %% [markdown]
# Quiero que me muestre loas ultimas 2 filas de mi DataFrame

# %%
mc.tail(2)
# Out:
#                Category                                               Item  \
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# 258  14.2 oz (403 g)       810                290       32.0
# 259   7.1 oz (202 g)       410                150       16.0
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 258                         50           15.0                             76
# 259                         25            8.0                             38
#
#      Trans Fat  ...  Carbohydrates  Carbohydrates (% Daily Value)  \
# 258        1.0  ...            114                             38
# 259        0.0  ...             57                             19
#
#      Dietary Fiber  Dietary Fiber (% Daily Value)  Sugars  Protein  \
# ...

# %% [markdown]
# Quiero que me muestre las primeras 5 filas y 3 columnas

# %%
mc.iloc[0:5,0:3]
# Out:
#     Category                              Item    Serving Size
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)

# %% [markdown]
# Si quiero saber el total de datos que tengo en mi DataFrame

# %%
mc.shape
# Out:
# (260, 24)

# %% [markdown]
# Para desplegar en general la informacion del dataFrame

# %%
mc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %% [markdown]
# Los estadisticos

# %%
mc.describe()
# Out:
#           Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count   260.000000         260.000000  260.000000                 260.000000
# mean    368.269231         127.096154   14.165385                  21.815385
# std     240.269886         127.875914   14.205998                  21.885199
# min       0.000000           0.000000    0.000000                   0.000000
# 25%     210.000000          20.000000    2.375000                   3.750000
# 50%     340.000000         100.000000   11.000000                  17.000000
# 75%     500.000000         200.000000   22.250000                  35.000000
# max    1880.000000        1060.000000  118.000000                 182.000000
#
#        Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  Cholesterol  \
# count     260.000000                     260.000000  260.000000   260.000000
# mean        6.007692                      29.965385    0.203846    54.942308
# ...

# %% [markdown]
# Quiero visualizar solo los estadisticos de las caloreias redondeando a 2 decimales los resultados

# %%
mc['Calories'].describe().round(2)
# Out:
# count     260.00
# mean      368.27
# std       240.27
# min         0.00
# 25%       210.00
# 50%       340.00
# 75%       500.00
# max      1880.00
# Name: Calories, dtype: float64

# %% [markdown]
# Si no quiero todos los estadisticos y solo quiero por ejemplo el valor maximo de una serie

# %%
print('El maximo de calorias en el menu es de : ',mc['Calories'].max())
# Out:
# El maximo de calorias en el menu es de :  1880

# %% [markdown]
# Combinemos dos condiciones sobre las calorias de los alimentos

# %%
c1=mc['Calories']>=1000
c2=mc['Calories']<=1880
mc[c1 & c2]['Calories']
# Out:
# 31    1090
# 32    1150
# 34    1050
# 82    1880
# Name: Calories, dtype: int64

# %% [markdown]
# Filtremos no por Serie, si no por una caracteristica que este dentro de una de las series, por ejemplo, los "Smoothies & Shakes" en la categoria...., despues ordenemoslo alfabeticamente

# %%
smoothies=mc[mc['Category']=='Smoothies & Shakes']
smoothies.sort_values('Item')
# Out:
#                Category                                               Item  \
# 234  Smoothies & Shakes             Blueberry Pomegranate Smoothie (Large)
# 233  Smoothies & Shakes            Blueberry Pomegranate Smoothie (Medium)
# 232  Smoothies & Shakes             Blueberry Pomegranate Smoothie (Small)
# 249  Smoothies & Shakes                            Chocolate Shake (Large)
# 248  Smoothies & Shakes                           Chocolate Shake (Medium)
# 247  Smoothies & Shakes                            Chocolate Shake (Small)
# 240  Smoothies & Shakes                   Mango Pineapple Smoothie (Large)
# 239  Smoothies & Shakes                  Mango Pineapple Smoothie (Medium)
# 238  Smoothies & Shakes                   Mango Pineapple Smoothie (Small)
# 253  Smoothies & Shakes               McFlurry with M&M’s Candies (Medium)
# 252  Smoothies & Shakes                McFlurry with M&M’s Candies (Small)
# ...

# %% [markdown]
# Otra manera de hacerlo seria

# %%
batidos = mc.iloc[232:260,:]['Item'].sort_values()
batidos
# Out:
# 234               Blueberry Pomegranate Smoothie (Large)
# 233              Blueberry Pomegranate Smoothie (Medium)
# 232               Blueberry Pomegranate Smoothie (Small)
# 249                              Chocolate Shake (Large)
# 248                             Chocolate Shake (Medium)
# 247                              Chocolate Shake (Small)
# 240                     Mango Pineapple Smoothie (Large)
# 239                    Mango Pineapple Smoothie (Medium)
# 238                     Mango Pineapple Smoothie (Small)
# 253                 McFlurry with M&M’s Candies (Medium)
# 252                  McFlurry with M&M’s Candies (Small)
# 254                  McFlurry with M&M’s Candies (Snack)
# 256                  McFlurry with Oreo Cookies (Medium)
# 255                   McFlurry with Oreo Cookies (Small)
# 257                   McFlurry with Oreo Cookies (Snack)
# 258    McFlurry with Reese's Peanut Butter Cups (Medium)
# ...
